# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
# STEP 2: Load the dataset
df = pd.read_csv("/content/AAA.csv")
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
# STEP 3: Basic cleanup and renaming for clarity
data.rename(columns={
    "Class": "Performance",
    "raisedhands": "HandsRaised",
    "VisitedResources": "ResourcesVisited"
}, inplace=True)

# %%
# STEP 4: Display first few rows
print("Sample Data:")
display(df.head())
# Out:
# Sample Data:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
# STEP 3: Basic cleanup and renaming for clarity
df.rename(columns={
    "Class": "Performance",
    "raisedhands": "HandsRaised",
    "VisitedResources": "ResourcesVisited"
}, inplace=True)

# %%
# STEP 6: Performance distribution
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Performance", palette="Set2")
plt.title("Performance Distribution (High, Medium, Low)")
plt.xlabel("Performance Category")
plt.ylabel("Number of Students")
plt.show()
# Out:
# <ipython-input-14-4150577928>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Performance", palette="Set2")

# %%
# STEP 7: Correlation heatmap
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))

# Corrected column name: VisITedResources
corr = df[['HandsRaised', 'VisITedResources', 'AnnouncementsView', 'Discussion']].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Between Participation Metrics")
plt.show()

# %%
# STEP 7: Correlation heatmap
plt.figure(figsize=(8,6))

# Add this line to inspect columns before the error
print("Columns before correlation calculation:", df.columns.tolist())

# Original code attempting correlation
# corr = df[['HandsRaised', 'ResourcesVisited', 'AnnouncementsView', 'Discussion']].corr()
# sns.heatmap(corr, annot=True, cmap="coolwarm")
# plt.title("Correlation Between Participation Metrics")
# plt.show()
# Out:
# Columns before correlation calculation: ['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID', 'SectionID', 'Topic', 'Semester', 'Relation', 'HandsRaised', 'VisITedResources', 'AnnouncementsView', 'Discussion', 'ParentAnsweringSurvey', 'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Performance']

# %%
# STEP 8: Boxplot to see impact of attendance on participation
plt.figure(figsize=(7,5))
sns.boxplot(data=df, x='StudentAbsenceDays', y='HandsRaised', palette="muted")
plt.title("Absenteeism vs Hands Raised")
plt.xlabel("Student Absence Days")
plt.ylabel("Number of Hands Raised")
plt.show()
# Out:
# <ipython-input-17-3541352744>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='StudentAbsenceDays', y='HandsRaised', palette="muted")

# %%
# STEP 9: Violin plot - Top vs Struggling students
plt.figure(figsize=(7,5))
sns.violinplot(data=df, x="Performance", y="HandsRaised", palette="pastel")
plt.title("Participation by Performance Category")
plt.xlabel("Performance")
plt.ylabel("Hands Raised")
plt.show()
# Out:
# <ipython-input-18-829360750>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="Performance", y="HandsRaised", palette="pastel")

# %%
# STEP 10: Define at-risk students
# Criteria: Low hands raised + low resource access + low grade

# Correct column names based on your DataFrame
required_columns = ['HandsRaised', 'VisITedResources', 'Performance']
missing_cols = [col for col in required_columns if col not in df.columns]

if missing_cols:
    print(f"❌ Missing columns in DataFrame: {missing_cols}")
else:
    # Filter students meeting all at-risk criteria
    at_risk = df[
        (df["HandsRaised"] < 10) &
        (df["VisITedResources"] < 50) &
        (df["Performance"].str.upper() == "L")
    ]

    print(f"\n🚨 At-Risk Students Found: {len(at_risk)}")

    # Try displaying key info
    try:
        display(at_risk[['gender', 'StageID', 'HandsRaised', 'VisITedResources',
                         'AnnouncementsView', 'Performance']])
    except KeyError as e:
        print(f"⚠️ Column error in display: {e}")
        print("Available columns are:", df.columns.tolist())

    # STEP 11: Save at-risk students for academic review
    try:
        at_risk.to_csv("at_risk_students.csv", index=False)
        print("\n✅ At-risk students saved to 'at_risk_students.csv'")
    except Exception as e:
        print(f"❌ Error saving file: {e}")
# Out:
# 🚨 At-Risk Students Found: 44
#     gender       StageID  HandsRaised  VisITedResources  AnnouncementsView  \
# 12       M    lowerlevel            5                 1                  0
# 23       M  MiddleSchool            2                 0                  2
# 24       M  MiddleSchool            0                 2                  3
# 25       M  MiddleSchool            8                 7                 30
# 31       M  MiddleSchool            4                 5                 40
# 32       F    lowerlevel            2                19                 10
# 33       M    lowerlevel            8                22                  9
# 36       M  MiddleSchool            8                 6                  4
# 38       M  MiddleSchool            0                 0                  0
# 46       M    lowerlevel            7                10                  1
# 57       M  MiddleSchool            5                 2                  6
# ...

# %%
# STEP 10: Define at-risk students
# Criteria: Low hands raised + low resource access + low grade

required_columns = ['HandsRaised', 'VisITedResources', 'Performance']
missing_cols = [col for col in required_columns if col not in df.columns]

if missing_cols:
    print(f"❌ Missing columns in DataFrame: {missing_cols}")
else:
    at_risk = df[
        (df["HandsRaised"] < 10) &
        (df["VisITedResources"] < 50) &
        (df["Performance"].str.upper() == "L")
    ]

    print(f"\n🚨 At-Risk Students Found: {len(at_risk)}")

    try:
        display(at_risk[['gender', 'StageID', 'HandsRaised', 'VisITedResources',
                         'AnnouncementsView', 'Performance']])
    except KeyError as e:
        print(f"⚠️ Column error in display: {e}")
        print("Available columns are:", df.columns.tolist())

    # STEP 11: Save at-risk students for academic review
    if at_risk.empty:
        print("⚠️ No at-risk students to save.")
    else:
        try:
            at_risk.to_csv("at_risk_students.csv", index=False)
            print("\n✅ At-risk students saved to 'at_risk_students.csv'")
        except Exception as e:
            print(f"❌ Error saving file: {e}")
# Out:
# 🚨 At-Risk Students Found: 44
#     gender       StageID  HandsRaised  VisITedResources  AnnouncementsView  \
# 12       M    lowerlevel            5                 1                  0
# 23       M  MiddleSchool            2                 0                  2
# 24       M  MiddleSchool            0                 2                  3
# 25       M  MiddleSchool            8                 7                 30
# 31       M  MiddleSchool            4                 5                 40
# 32       F    lowerlevel            2                19                 10
# 33       M    lowerlevel            8                22                  9
# 36       M  MiddleSchool            8                 6                  4
# 38       M  MiddleSchool            0                 0                  0
# 46       M    lowerlevel            7                10                  1
# 57       M  MiddleSchool            5                 2                  6
# ...

# %%
#  command to display the content of the CSV file
# !cat at_risk_students.csv
# Out:
# gender,NationalITy,PlaceofBirth,StageID,GradeID,SectionID,Topic,Semester,Relation,HandsRaised,VisITedResources,AnnouncementsView,Discussion,ParentAnsweringSurvey,ParentschoolSatisfaction,StudentAbsenceDays,Performance
# M,KW,KuwaIT,lowerlevel,G-04,A,IT,F,Father,5,1,0,11,No,Bad,Above-7,L
# M,KW,KuwaIT,MiddleSchool,G-07,A,IT,F,Father,2,0,2,50,No,Bad,Above-7,L
# M,KW,KuwaIT,MiddleSchool,G-07,B,IT,F,Father,0,2,3,70,Yes,Good,Above-7,L
# M,KW,KuwaIT,MiddleSchool,G-07,A,IT,F,Father,8,7,30,40,Yes,Good,Above-7,L
# M,KW,KuwaIT,MiddleSchool,G-07,A,IT,F,Father,4,5,40,16,Yes,Good,Above-7,L
# F,KW,KuwaIT,lowerlevel,G-07,A,IT,F,Father,2,19,10,50,Yes,Good,Above-7,L
# M,KW,KuwaIT,lowerlevel,G-05,A,English,F,Father,8,22,9,40,No,Bad,Above-7,L
# M,KW,KuwaIT,MiddleSchool,G-07,B,Science,F,Mum,8,6,4,22,Yes,Good,Above-7,L
# M,KW,KuwaIT,MiddleSchool,G-06,A,IT,F,Father,0,0,0,4,No,Bad,Above-7,L
# M,KW,KuwaIT,lowerlevel,G-05,A,English,F,Father,7,10,1,30,No,Bad,Above-7,L
# ...
